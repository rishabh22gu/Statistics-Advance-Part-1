# %% [markdown]
# Q.1- Random Variable in Probability Theory
# A random variable is a function that assigns numerical values to outcomes of a random experiment. It can take different values based on the experiment's outcome.
#
# Q.2- Types of Random Variables
# Discrete Random Variable: Takes a countable number of distinct values (e.g., the number of heads in coin flips).
# Continuous Random Variable: Takes an uncountable number of values within a given range (e.g., a person's height or temperature).
#
# Q.3- Difference Between Discrete and Continuous Distributions
# Discrete distributions deal with countable values (e.g., number of defective items in a batch).
# Continuous distributions deal with measurable values over an interval (e.g., weights of newborn babies).
#
# Q.4- Probability Distribution Function (PDF)
#
# A probability distribution function describes how probabilities are distributed over the values of a random variable.
#
# For discrete variables, it is called the Probability Mass Function (PMF).
# For continuous variables, it is called the Probability Density Function (PDF).
#
# Q.5- Cumulative Distribution Function (CDF) vs. Probability Distribution Function (PDF)
#
# The CDF gives the probability that a random variable is less than or equal to a particular value.
# The PDF (for continuous variables) or PMF (for discrete variables) gives the probability of a specific value occurring.
#
# Q.6- Discrete Uniform Distribution
#
# A distribution where all possible values of a discrete random variable are equally likely. Example: Rolling a fair die.
#
# Q.7- Key Properties of Bernoulli Distribution
# Describes a single trial with two possible outcomes (Success = 1, Failure = 0).
# Probability of success: 𝑝, probability of failure: 1−𝑝.
# Mean:𝑝, Variance: 𝑝(1−p).
#
# Q.8- Binomial Distribution
# Represents the number of successes in n independent Bernoulli trials.
# Probability formula: P(X=k)=( n/k )p k (1−p) n−k
# where
# k is the number of successes,
# p is the success probability.
#
# Q.9- Poisson Distribution and Its Application
# Used for modeling the number of events in a fixed interval of time/space.
#
# Q.10- Continuous Uniform Distribution
# A constant probability for all values in a range [a,b]
#
# 11- Characteristics of a Normal Distribution
# Symmetric, bell-shaped curve.
# Defined by mean 𝜇μ and standard deviation 𝜎σ.
# 68-95-99.7 Rule: About 68% of values fall within 1σ, 95% within 2𝜎, 99.7% within 3σ.
#
# Q.12- Standard Normal Distribution
# A special case of the normal distribution with mean 0 and standard deviation 1.
# Used for standardization (converting values into Z-scores).
#
# Q.13- Central Limit Theorem (CLT) and Its Importance
# States that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the original distribution.
# Crucial because it allows us to use normal distribution approximations in many statistical analyses.
#
# Q.14- How CLT Relates to the Normal Distribution
# When sample size is large (𝑛≥30, the distribution of the sample mean is approximately normal, even if the population distribution is not.
#
# Q.15- Application of Z-Statistics in Hypothesis Testing
# Used to test hypotheses when population parameters are known.
# Helps in determining p-values and rejecting/accepting null hypotheses.
#
# 16- The formula for calculating a z-score is z = (x-μ)/σ, where x is the raw score, μ is the population mean, and σ is the population standard deviation. As the formula shows, the z-score is simply the raw score minus the population mean, divided by the population standard deviation
#
# Q.17- Point Estimates vs. Interval Estimates
# Point Estimate: A single value estimate of a parameter (e.g., sample mean).
# Interval Estimate: A range within which the parameter is expected to lie (e.g., confidence interval).
#
# Q.18- Significance of Confidence Intervals
# Indicates the range in which the true population parameter is likely to be found.
# A 95% confidence interval means we are 95% confident that the parameter falls within the interval.
#
# 19- Relationship Between Z-Score and Confidence Interval
# Z-scores determine confidence intervals for normally distributed data.
# Example: For a 95% confidence level, 𝑍=1.96.
#
# 20- Using Z-Scores to Compare Different Distributions
# Standardizes different distributions by converting values to a common scale.
# Helps in comparing data points from different datasets.
#
# 21- Assumptions for Applying the Central Limit Theorem
# The sample size should be sufficiently large (𝑛≥30.
# Samples should be independent.
# The population should not have extreme skewness if the sample size is small.
#
# 22- Expected Value in a Probability Distribution
# The long-term average outcome of a random variable.
# Formula:𝐸(𝑋)=∑𝑥𝑃(𝑥)(discrete)or𝐸(𝑋)=∫𝑥𝑓(𝑥)𝑑𝑥(continuous)
#
# 23- Relation Between Probability Distribution and Expected Outcome
# The expected value gives a central tendency of a probability distribution, indicating where values are likely to be centered.

# %% [markdown]
# PRACTICAL QUESTION

# %%
#1
import random

# Generate a random variable between 1 and 100
random_var = random.randint(1, 100)
print("Random Variable:", random_var)
# Out:
# Random Variable: 82

# %%
#2
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define discrete uniform distribution parameters
low, high = 1, 6  # Simulating a fair die roll
x = np.arange(low, high+1)
pmf = stats.randint.pmf(x, low, high+1)

# Plot PMF
plt.bar(x, pmf, alpha=0.7, color='b', edgecolor='black')
plt.xlabel("Values")
plt.ylabel("Probability")
plt.title("Discrete Uniform Distribution PMF")
plt.show()

# %%
#3
def bernoulli_pdf(p, x):
    return p**x * (1 - p)**(1 - x)

# Example usage
p = 0.5
x_values = [0, 1]
pdf_values = [bernoulli_pdf(p, x) for x in x_values]
print("Bernoulli PDF:", pdf_values)
# Out:
# Bernoulli PDF: [0.5, 0.5]

# %%
#4
n, p = 10, 0.5
samples = np.random.binomial(n, p, 1000)

plt.hist(samples, bins=range(n+2), density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.show()

# %%
#5
lam = 4
poisson_samples = np.random.poisson(lam, 1000)

plt.hist(poisson_samples, bins=15, density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Occurrences")
plt.ylabel("Probability")
plt.title("Poisson Distribution Histogram")
plt.show()

# %%
#6
cdf = stats.randint.cdf(x, low, high+1)

plt.step(x, cdf, where="mid", color='r')
plt.xlabel("Values")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (CDF)")
plt.show()

# %%
#7
continuous_uniform_samples = np.random.uniform(0, 1, 1000)

plt.hist(continuous_uniform_samples, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Continuous Uniform Distribution")
plt.show()

# %%
#8
normal_samples = np.random.normal(0, 1, 1000)

plt.hist(normal_samples, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Normal Distribution Histogram")
plt.show()

# %%
#9
def calculate_z_scores(data):
    return (data - np.mean(data)) / np.std(data)

data = np.random.normal(50, 10, 100)
z_scores = calculate_z_scores(data)

plt.hist(z_scores, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Z-Score")
plt.ylabel("Density")
plt.title("Z-Score Distribution")
plt.show()

# %%
#10
samples = 1000
sample_size = 30
non_normal_data = np.random.exponential(scale=2, size=(samples, sample_size))
sample_means = np.mean(non_normal_data, axis=1)

plt.hist(sample_means, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Central Limit Theorem Demonstration")
plt.show()

# %%
#11
normal_samples = np.random.normal(10, 5, (1000, 30))
sample_means = np.mean(normal_samples, axis=1)

plt.hist(sample_means, bins=30, density=True, alpha=0.7, edgecolor='black')
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.title("Verification of Central Limit Theorem")
plt.show()

# %%
#12
x = np.linspace(-4, 4, 100)
pdf = stats.norm.pdf(x, 0, 1)

plt.plot(x, pdf, color='b')
plt.xlabel("Z-Score")
plt.ylabel("Density")
plt.title("Standard Normal Distribution")
plt.show()

# %%
#13
binomial_samples = np.random.binomial(10, 0.5, 1000)
unique, counts = np.unique(binomial_samples, return_counts=True)
probabilities = counts / len(binomial_samples)

plt.bar(unique, probabilities, alpha=0.7, color='b', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Probability")
plt.title("Binomial Distribution")
plt.show()

# %%
#14
data_point = 55
mean = 50
std_dev = 10
z_score = (data_point - mean) / std_dev
print("Z-Score:", z_score)
# Out:
# Z-Score: 0.5

# %%
#15
from scipy.stats import norm

sample_mean = 52
population_mean = 50
std_dev = 10
n = 30

z_statistic = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_statistic)))

print("Z-Statistic:", z_statistic)
print("P-Value:", p_value)
# Out:
# Z-Statistic: 1.0954451150103321
# P-Value: 0.27332167829229803

# %%
#16
sample = np.random.normal(50, 10, 30)
mean, std_dev = np.mean(sample), np.std(sample, ddof=1)
confidence = 0.95
margin_error = stats.norm.ppf((1 + confidence) / 2) * (std_dev / np.sqrt(len(sample)))

ci_lower, ci_upper = mean - margin_error, mean + margin_error
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval: (47.49, 54.55)

# %%
#17
x = np.linspace(-4, 4, 100)
pdf = stats.norm.pdf(x)

plt.plot(x, pdf, color='b')
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Normal Distribution PDF")
plt.show()

# %%
#18
x = np.arange(0, 15)
poisson_cdf = stats.poisson.cdf(x, mu=4)

plt.step(x, poisson_cdf, where="mid", color='r')
plt.xlabel("Occurrences")
plt.ylabel("Cumulative Probability")
plt.title("Poisson CDF")
plt.show()

# %%
#19
data = np.random.uniform(0, 1, 1000)
expected_value = np.mean(data)
print("Expected Value:", expected_value)
# Out:
# Expected Value: 0.5097378446385152

# %%
#20
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(60, 15, 1000)

print("Standard Deviation of Dataset 1:", np.std(data1))
print("Standard Deviation of Dataset 2:", np.std(data2))
# Out:
# Standard Deviation of Dataset 1: 9.998599413298733
# Standard Deviation of Dataset 2: 15.486951685693736
